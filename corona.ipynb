# %%
import pandas as pd  
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import mplcursors

# %%
first_file = pd.read_csv("C:\\country_wise_latest.csv")

# %%
first_file.head()
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0     Afghanistan      36263    1269      25198    9796        106
# 1         Albania       4880     144       2745    1991        117
# 2         Algeria      27973    1163      18837    7973        616
# 3         Andorra        907      52        803      52         10
# 4          Angola        950      41        242     667         18
# ..            ...        ...     ...        ...     ...        ...
# 95         Latvia       1219      31       1045     143          0
# 96        Lebanon       3882      51       1709    2122        132
# 97        Lesotho        505      12        128     365          0
# 98        Liberia       1167      72        646     449          5
# 99          Libya       2827      64        577    2186        158
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0           10             18                3.50                  69.49
# ...

# %%
sns.set(color_codes=True)

# %%
first_file.shape
# Out:
# (187, 15)

# %%
first_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
missing_values = first_file.isnull().sum()

# %%
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
missing_percentage = (first_file.isnull().sum() / len(first_file)) * 100

# %%
print("Missing Percentage:\n", missing_percentage)
# Out:
# Missing Percentage:
#  Country/Region            0.0
# Confirmed                 0.0
# Deaths                    0.0
# Recovered                 0.0
# Active                    0.0
# New cases                 0.0
# New deaths                0.0
# New recovered             0.0
# Deaths / 100 Cases        0.0
# Recovered / 100 Cases     0.0
# Deaths / 100 Recovered    0.0
# Confirmed last week       0.0
# 1 week change             0.0
# 1 week % increase         0.0
# WHO Region                0.0
# dtype: float64

# %%
sorted_missing_values = missing_values.sort_values(ascending=False)

# %%
print("Sorted Missing Values:\n", sorted_missing_values)
# Out:
# Sorted Missing Values:
#  Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
data = {
    'Country/Region': ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola'],
    'Confirmed': [36263, 4880, 27973, 907, 950],
    'Recovered': [25198, 2745, 18837, 803, 242]
}

df = pd.DataFrame(data)

# Sort the DataFrame by 'Confirmed' in descending order and select the top 20
df_sorted = df.sort_values(by='Confirmed', ascending=False).head(20)

# Plotting
plt.figure(figsize=(5, 8))
plt.bar(df_sorted['Country/Region'], df_sorted['Confirmed'], label='Confirmed', color='red', alpha=0.7)
plt.bar(df_sorted['Country/Region'], df_sorted['Recovered'], label='Recovered', color='green', alpha=0.7)

plt.xlabel('Country/Region', fontsize=10)
plt.ylabel('Number of Cases', fontsize=10)
plt.title('Top 20 Countries by Confirmed Cases', fontsize=12)
plt.legend()

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

plt.show()

# %%
df_sorted = df.sort_values(by='Confirmed', ascending=True).head(10)

# Plotting total confirmed cases for the top 10 countries
plt.figure(figsize=(8, 3))
plt.barh(df_sorted['Country/Region'], df_sorted['Confirmed'], color='blue', alpha=0.7)

plt.xlabel('Number of Confirmed Cases', fontsize=10)
plt.ylabel('Country/Region', fontsize=10)
plt.title('confirmed cases by top 10 countries', fontsize=12)

plt.tight_layout()

plt.show()

# %%
df = pd.DataFrame(data)

# Calculate death rate (deaths / confirmed) and sort the DataFrame by it
df['Death Rate'] = df['Deaths'] / df['Confirmed']
df_sorted = df.sort_values(by='Death Rate', ascending=False)

# Plotting death rate for each country
plt.figure(figsize=(8, 6))
plt.barh(df_sorted['Country/Region'], df_sorted['Death Rate'], color='purple', alpha=0.7)

plt.xlabel('Death Rate', fontsize=10)
plt.ylabel('Country/Region', fontsize=10)
plt.title('Death Rate by Country', fontsize=12)

plt.tight_layout()

plt.show()

# %%
data = {
    'Country/Region': ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola'],
    'Confirmed': [36263, 4880, 27973, 907, 950],
    'Deaths': [1269, 144, 1163, 52, 41],
    'Recovered': [25198, 2745, 18837, 803, 242],
    'Active': [9796, 1991, 7973, 52, 667],
    'New cases': [106, 117, 616, 10, 18],
    'New deaths': [10, 6, 8, 0, 1],
    'New recovered': [18, 63, 749, 0, 0],
}

df = pd.DataFrame(data)

# Sum up the values for the entire dataset
total_active = df['Active'].sum()
total_new_cases = df['New cases'].sum()
total_new_deaths = df['New deaths'].sum()

# Data for the pie chart
labels = ['Active', 'New Cases', 'New Deaths']
sizes = [total_active, total_new_cases, total_new_deaths]
colors = ['yellow', 'lightblue', 'lightcoral']

# Plotting the pie chart
plt.figure(figsize=(5, 10))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Active, New Cases, and New Deaths Across Countries')

plt.show()

# %%
data = {
    'Country/Region': ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola'],
    'Confirmed': [36263, 4880, 27973, 907, 950],
    'Deaths': [1269, 144, 1163, 52, 41],
    'Recovered': [25198, 2745, 18837, 803, 242],
    'Active': [9796, 1991, 7973, 52, 667],
    'New cases': [106, 117, 616, 10, 18],
    'New deaths': [10, 6, 8, 0, 1],
    'New recovered': [18, 63, 749, 0, 0],
    'Confirmed last week': [35526, 4171, 23691, 884, 749],
}

df = pd.DataFrame(data)

# Plotting last week confirmed cases for each country
plt.figure(figsize=(6, 8))
plt.bar(df['Country/Region'], df['Confirmed last week'], color='orange', alpha=0.7)

plt.xlabel('Country/Region', fontsize=10)
plt.ylabel('Confirmed Cases Last Week', fontsize=10)
plt.title('Last Week  confirmed cases by Country', fontsize=12)

plt.xticks(rotation=45, ha='right')  
plt.tight_layout()

plt.show()
